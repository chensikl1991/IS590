# %% [markdown]
# ## IS590PR
# Examples to introduce Pandas and typical operations with a single large "table" of data.
#
# The first data file used here comes from
# https://data.nodc.noaa.gov/cgi-bin/iso?id=gov.noaa.ngdc.mgg.hazards:G10147

# %%
import pandas as pd
import numpy as np

# %%
v = pd.read_csv('Data/NOAA_Signif_Volcano_Eruptions_20181003.txt',
               sep='\t')  # it's a TAB-separated file.

# %%
v.head()
# Out:
#    Year  Month  Day  TSU   EQ             Name            Location  \
# 0 -4360    NaN  NaN  NaN  NaN  Macauley Island         Kermadec Is
# 1 -4350    NaN  NaN  NaN  NaN            Kikai           Ryukyu Is
# 2 -4050    NaN  NaN  NaN  NaN           Masaya           Nicaragua
# 3 -4000    NaN  NaN  NaN  NaN             Pago  New Britain-SW Pac
# 4 -3580    NaN  NaN  NaN  NaN             Taal   Luzon-Philippines
#
#             Country  Latitude  Longitude   ...    TOTAL_MISSING  \
# 0       New Zealand   -30.200   -178.470   ...              NaN
# 1             Japan    30.780    130.280   ...              NaN
# 2         Nicaragua    11.984    -86.161   ...              NaN
# 3  Papua New Guinea    -5.580    150.520   ...              NaN
# 4       Philippines    14.002    120.993   ...              NaN
#
#   TOTAL_MISSING_DESCRIPTION TOTAL_INJURIES TOTAL_INJURIES_DESCRIPTION  \
# 0                       NaN            NaN                        NaN
# 1                       NaN            NaN                        NaN
# 2                       NaN            NaN                        NaN
# 3                       NaN            NaN                        NaN
# 4                       NaN            NaN                        NaN
#
#    TOTAL_DAMAGE_MILLIONS_DOLLARS TOTAL_DAMAGE_DESCRIPTION  \
# 0                            NaN                      NaN
# 1                            NaN                      3.0
# 2                            NaN                      NaN
# 3                            NaN                      1.0
# 4                            NaN                      NaN
#
#    TOTAL_HOUSES_DESTROYED  TOTAL_HOUSES_DESTROYED_DESCRIPTION  TD_MIN  TD_MAX
# 0                     NaN                                 NaN     NaN     NaN
# 1                     NaN                                 3.0   101.0  1000.0
# 2                     NaN                                 NaN     NaN     NaN
# 3                     NaN                                 NaN     1.0    50.0
# 4                     NaN                                 NaN     NaN     NaN
#
# [5 rows x 38 columns]

# %%
v.tail()

# %% [markdown]
# After reviewing whether the data got loaded and formatted properly, we see that some data types are inappropriate.  Especially notice how columns like 'Month', 'Day', and 'TOTAL_DEATHS' should be integers, right?
#
# We could force those to be integers but unfortunately, if we do that, we lose support for the np.NaN values, which mean "Not a Number".  If you look through the data you'll see there are many numeric columns that have missing values.  With NaN support, we automatically get correct results for calculations like arithmetic means or standard deviations even when there are some missing values.

# %% [markdown]
# ### Grouping data
# Let's calculate some statistics that require grouping.  You can usually tell you need grouping because the English-language description of your result has the word "each" or "per" in it:
#
# * Number of distinct volcanoes *per country*.
# * Number of eruptions *per year*.
# * Number of eruptions *per century*.
# * etc.

# %% [markdown]
# ### Number of eruptions per year
# First try just getting a specific year's data (2018).  We have to first calculate a Series of Boolean values by vectorizing a comparison.  That result gets used as the "slice" of the dataframe again so we get just the rows we want.

# %%
v[v['Year'] >= 2010]

# %% [markdown]
# But to count PER year, we need to do several things:
# * groupby() the 'Year' column to collapse all rows with matching years together.
# * call the size() method to give us the number of rows that got collapsed.
#
# Note that the count() method sounds more intuitive here than size() but it does something different...

# %%
v.groupby('Year').size()
# Out:
#         0
# Year
# -4360   1
# -4350   1
# -4050   1
# -4000   1
# -3580   1
# -3550   1
# -2420   1
# -2040   1
# -1900   1
# -1860   1
# -1750   1
# -1645   1
# -1610   1
# -1550   1
# -1460   1
# -1370   1
# -1050   1
# -1010   1
# -455    1
# -250    1
# -197    1
# -150    1
# -141    1
# -100    1
# -50     1
#  46     1
#  50     1
#  60     1
#  79     1
#  200    1
# ...    ..
#  1989   2
#  1990  10
#  1991   7
#  1992   8
#  1993   9
#  1994   7
#  1995   6
#  1996   6
#  1997   9
#  1998   3
#  1999   5
#  2000   5
#  2001   4
#  2002   6
#  2003   1
#  2004   3
#  2005   3
#  2006   7
#  2007   4
#  2008   4
#  2009   2
#  2010   9
#  2011  10
#  2012   3
#  2013   8
#  2014   6
#  2015   6
#  2016   5
#  2017   8
#  2018  11
#
# [354 rows x 1 columns]

# %% [markdown]
# ### Tricky Counting
# Suppose we have to produce a report of
# "List Countries by the total (approximate) number of deaths from volcanoes"
#
# It turns out that this is harder than it seems, because of the way the data is currently encoded.  If we just add up the "TOTAL_DEATHS" column values, we'll be **way underreporting** the fatalities.  Review the NOAA published metadata regarding columns like TOTAL_DEATH_DESCRIPTION.
#
# You'll see that column only contains 1, 2, 3, or 4, which are approximate range indicators.  TOTAL_DEATHS is only filled out if they're confident in a **specific** number.

# %% [markdown]
# ### Bulk modifications of selected data
# So we need to create some new columns to help us figure out the range of the estimated death tolls...

# %%
deaths = v[['Year', 'Day', 'Month', 'TOTAL_DEATHS',  'TOTAL_DEATHS_DESCRIPTION', 'Country', 'Name', 'Location']]

# %%
deaths.head()

# %%
deaths[deaths['TOTAL_DEATHS'] > 0]

# %%
deaths['TOTAL_DEATHS'].max()

# %%
conv = {1: (1, 50),
        2: (51, 100), 
        3: (101, 1000),
        4: (1001, 100000)
       }

# %%
deaths.head()

# %%
v['TD_MIN'] = np.NaN
v['TD_MAX'] = np.NaN

# %%
for x in range(1,5):
    rows = v['TOTAL_DEATHS_DESCRIPTION'] == x
    v.loc[rows, 'TD_MIN'] = conv[x][0]
    v.loc[rows, 'TD_MAX'] = conv[x][1]

# %%
v[['TD_MIN','TD_MAX','TOTAL_DEATHS','TOTAL_DEATHS_DESCRIPTION']]
# Out:
#      TD_MIN  TD_MAX  TOTAL_DEATHS  TOTAL_DEATHS_DESCRIPTION
# 0       NaN     NaN           NaN                       NaN
# 1     101.0  1000.0           NaN                       3.0
# 2       NaN     NaN           NaN                       NaN
# 3       1.0    50.0           NaN                       1.0
# 4       NaN     NaN           NaN                       NaN
# 5       NaN     NaN           NaN                       NaN
# 6       NaN     NaN           NaN                       NaN
# 7       NaN     NaN           NaN                       NaN
# 8       NaN     NaN           NaN                       NaN
# 9       NaN     NaN           NaN                       NaN
# 10      NaN     NaN           NaN                       NaN
# 11      NaN     NaN           NaN                       NaN
# 12    101.0  1000.0           NaN                       3.0
# 13      NaN     NaN           NaN                       NaN
# 14      NaN     NaN           NaN                       NaN
# 15      NaN     NaN           NaN                       NaN
# 16      NaN     NaN           NaN                       NaN
# 17    101.0  1000.0           NaN                       3.0
# 18      1.0    50.0           NaN                       1.0
# 19      NaN     NaN           NaN                       NaN
# 20      NaN     NaN           NaN                       NaN
# 21    101.0  1000.0           NaN                       3.0
# 22     40.0    40.0          40.0                       1.0
# 23      NaN     NaN           NaN                       NaN
# 24      NaN     NaN           NaN                       NaN
# 25      NaN     NaN           NaN                       NaN
# 26      NaN     NaN           NaN                       NaN
# 27      NaN     NaN           NaN                       NaN
# 28   2100.0  2100.0        2100.0                       4.0
# 29      NaN     NaN           NaN                       NaN
# ..      ...     ...           ...                       ...
# 790     NaN     NaN           NaN                       NaN
# 791     NaN     NaN           NaN                       NaN
# 792     NaN     NaN           NaN                       NaN
# 793     NaN     NaN           NaN                       NaN
# 794     1.0     1.0           1.0                       1.0
# 795     1.0     1.0           1.0                       1.0
# 796     1.0     1.0           1.0                       1.0
# 797     7.0     7.0           7.0                       1.0
# 798     1.0     1.0           1.0                       1.0
# 799     NaN     NaN           NaN                       NaN
# 800     NaN     NaN           NaN                       NaN
# 801     NaN     NaN           NaN                       NaN
# 802     NaN     NaN           NaN                       NaN
# 803     NaN     NaN           NaN                       NaN
# 804     8.0     8.0           8.0                       1.0
# 805     3.0     3.0           3.0                       1.0
# 806     NaN     NaN           NaN                       NaN
# 807     8.0     8.0           8.0                       1.0
# 808     NaN     NaN           NaN                       NaN
# 809     NaN     NaN           NaN                       NaN
# 810     NaN     NaN           NaN                       NaN
# 811     1.0     1.0           1.0                       1.0
# 812     1.0     1.0           1.0                       1.0
# 813     NaN     NaN           NaN                       NaN
# 814     NaN     NaN           NaN                       NaN
# 815     NaN     NaN           NaN                       NaN
# 816     4.0     4.0           4.0                       1.0
# 817   165.0   165.0         165.0                       3.0
# 818     NaN     NaN           NaN                       NaN
# 819     NaN     NaN           NaN                       NaN
#
# [820 rows x 4 columns]

# %% [markdown]
# Next we want to copy the precise death tolls into the TD_MIN and TD_MAX columns.

# %%
rows = v['TOTAL_DEATHS'] > 0
v.loc[rows, 'TD_MIN'] = v['TOTAL_DEATHS']
v.loc[rows, 'TD_MAX'] = v['TOTAL_DEATHS']

# %% [markdown]
# ### How many deaths estimated for all time?

# %%
print('Total Deaths estimated between {} and {}.'.format(
    v['TD_MIN'].sum(),
    v['TD_MAX'].sum()))
# Out:
# Total Deaths estimated between 338870.0 and 479890.0.

# %% [markdown]
# ## How many eruptions has Mt. Vesuvius had?

# %%
v[v['Name'] == 'Vesuvius']
# Out:
#      Year  Month   Day  TSU   EQ      Name Location Country  Latitude  \
# 6   -2420    NaN   NaN  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 28     79    8.0  25.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 42    787    NaN   NaN  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 118  1631   12.0  16.0  TSU   EQ  Vesuvius    Italy   Italy    40.821
# 141  1682    8.0  12.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 143  1690    2.0   3.0  TSU  NaN  Vesuvius    Italy   Italy    40.821
# 149  1698    5.0   NaN  TSU  NaN  Vesuvius    Italy   Italy    40.821
# 157  1714    6.0  30.0  TSU  NaN  Vesuvius    Italy   Italy    40.821
# 175  1737    5.0  20.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 195  1779    8.0   8.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 211  1794    6.0  15.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 222  1805    8.0  11.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 225  1813    5.0   NaN  TSU  NaN  Vesuvius    Italy   Italy    40.821
# 312  1872    4.0  24.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 317  1873    NaN   NaN  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 379  1905    3.0  10.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
# 381  1906    4.0   4.0  TSU  NaN  Vesuvius    Italy   Italy    40.821
# 469  1944    3.0  27.0  NaN  NaN  Vesuvius    Italy   Italy    40.821
#
#      Longitude                 ...                  TOTAL_DEATHS  \
# 6       14.426                 ...                           NaN
# 28      14.426                 ...                        2100.0
# 42      14.426                 ...                           NaN
# 118     14.426                 ...                        4000.0
# 141     14.426                 ...                           4.0
# 143     14.426                 ...                           NaN
# 149     14.426                 ...                           NaN
# 157     14.426                 ...                           NaN
# 175     14.426                 ...                           2.0
# 195     14.426                 ...                           NaN
# 211     14.426                 ...                         400.0
# 222     14.426                 ...                           4.0
# 225     14.426                 ...                           NaN
# 312     14.426                 ...                           9.0
# 317     14.426                 ...                           9.0
# 379     14.426                 ...                           1.0
# 381     14.426                 ...                         350.0
# 469     14.426                 ...                          27.0
#
#     TOTAL_DEATHS_DESCRIPTION TOTAL_MISSING TOTAL_MISSING_DESCRIPTION  \
# 6                        NaN           NaN                       NaN
# 28                       4.0           NaN                       NaN
# 42                       1.0           NaN                       NaN
# 118                      4.0           NaN                       NaN
# 141                      1.0           NaN                       NaN
# 143                      NaN           NaN                       NaN
# 149                      NaN           NaN                       NaN
# 157                      NaN           NaN                       NaN
# 175                      1.0           NaN                       NaN
# 195                      1.0           NaN                       NaN
# 211                      3.0           NaN                       NaN
# 222                      1.0           NaN                       NaN
# 225                      NaN           NaN                       NaN
# 312                      1.0           NaN                       NaN
# 317                      1.0           NaN                       NaN
# 379                      1.0           NaN                       NaN
# 381                      3.0           NaN                       NaN
# 469                      1.0           NaN                       NaN
#
#      TOTAL_INJURIES TOTAL_INJURIES_DESCRIPTION  TOTAL_DAMAGE_MILLIONS_DOLLARS  \
# 6               NaN                        NaN                            NaN
# 28              NaN                        NaN                            NaN
# 42              NaN                        NaN                            NaN
# 118             NaN                        NaN                            NaN
# 141             NaN                        NaN                            NaN
# 143             NaN                        NaN                            NaN
# 149             NaN                        NaN                            NaN
# 157             NaN                        NaN                            NaN
# 175             NaN                        NaN                            NaN
# 195             NaN                        NaN                            NaN
# 211             NaN                        NaN                            NaN
# 222             NaN                        NaN                            NaN
# 225             NaN                        NaN                            NaN
# 312            11.0                        1.0                            NaN
# 317             NaN                        NaN                            NaN
# 379             1.0                        1.0                            NaN
# 381           300.0                        3.0                            NaN
# 469             NaN                        NaN                            NaN
#
#      TOTAL_DAMAGE_DESCRIPTION  TOTAL_HOUSES_DESTROYED  \
# 6                         NaN                     NaN
# 28                        NaN                     NaN
# 42                        1.0                     NaN
# 118                       4.0                     NaN
# 141                       NaN                     NaN
# 143                       NaN                     NaN
# 149                       NaN                     NaN
# 157                       NaN                     NaN
# 175                       2.0                     NaN
# 195                       NaN                     NaN
# 211                       3.0                     NaN
# 222                       NaN                     NaN
# 225                       NaN                     NaN
# 312                       NaN                     NaN
# 317                       NaN                     NaN
# 379                       NaN                     NaN
# 381                       NaN                     NaN
# 469                       NaN                     NaN
#
#      TOTAL_HOUSES_DESTROYED_DESCRIPTION
# 6                                   NaN
# 28                                  NaN
# 42                                  NaN
# 118                                 4.0
# 141                                 NaN
# 143                                 NaN
# 149                                 NaN
# 157                                 NaN
# 175                                 NaN
# 195                                 NaN
# 211                                 NaN
# 222                                 NaN
# 225                                 NaN
# 312                                 NaN
# 317                                 NaN
# 379                                 NaN
# 381                                 NaN
# 469                                 NaN
#
# [18 rows x 36 columns]

# %%
v[v['Name'] == 'Vesuvius'].shape[0]
# Out:
# 18
